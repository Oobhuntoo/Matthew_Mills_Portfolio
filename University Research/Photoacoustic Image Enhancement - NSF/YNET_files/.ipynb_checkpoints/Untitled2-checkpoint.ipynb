# %%
import cv2
import glob
import numpy as np

from keras.layers import concatenate
from keras.layers import Dropout
from keras.layers import Conv2D, MaxPooling2D, Conv2DTranspose, BatchNormalization, Activation
from keras.engine.input_layer import Input
import keras
import tensorflow as tf
import time

from keras.preprocessing.image import ImageDataGenerator
import elasticdeform
import elasticdeform.tf as etf
import matplotlib.pyplot as plt

#https://www.kaggle.com/bguberfain/elastic-transform-for-data-augmentation


import torch
import torch.nn as nn

# %%
displacement_val = numpy.random.randn(2, 3, 3) * 5
X_val = numpy.random.rand(200, 300)
dY_val = numpy.random.rand(200, 300)

# construct TensorFlow input and top gradient
displacement = tf.Variable(displacement_val)
X = tf.Variable(X_val)
dY = tf.Variable(dY_val)

# the deform_grid function is similar to the plain Python equivalent,
# but it accepts and returns TensorFlow Tensors
X_deformed = etf.deform_grid(X, displacement, order=3)

def make_image_set(path):
    
    data = []
    files = list(glob.glob(path))
    files.sort()
    
    displacement_val = numpy.random.randn(2, 3, 3) * 5
    displacement = tf.Variable(displacement_val)
    
    for myFile in files:
        print(myFile)
        image = cv2.imread(myFile)
        plt.imshow(image)
        image = cv2.resize(image, (128,128))[:,:,0]
        image = etf.deform_grid(image, displacement, order=3)

        data.append(image)
        
    np_data = np.array(data)

    return np_data

# %%
x_train_path = r"C:/Users/Matthew/Desktop/YNET2/YNET_files/UNET/training/time_reversal/*.png"
y_train_path = r"C:/Users/Matthew/Desktop/YNET2/YNET_files/UNET/training/gt/*.png"


x_train = make_image_set(x_train_path)
x_test = make_image_set(x_test_path)
y_train = make_image_set(y_train_path)
y_test = make_image_set(y_test_path)

x_train = np.reshape(x_train, (96,128,128,1))
x_test = np.reshape(x_test, (24,128,128,1))

y_train = np.reshape(y_train, (96,128,128,1))
y_test = np.reshape(y_test, (24,128,128,1))


def norm(x):
    return (x.astype(np.float32) - 128.0) / 128.0

x_train = norm(x_train)
x_test = norm(x_test)
y_train = norm(y_train)
y_test = norm(y_test)

# %%
def show(x):
    plt.figure()
    plt.imshow((128*np.squeeze(x) + 128).astype(np.uint8), cmap='gray')

for x, y in zip(x_train, y_train):
    pred = model.predict(x.reshape(1,128,128,1))
    show(x)
    show(y)
    show(pred)

# %%
x_path = r"C:\Users\Matthew\Desktop\YNET2\YNET_files\UNET\training\time_reversal\recon01.png"
y_path = r"C:\Users\Matthew\Desktop\YNET2\YNET_files\UNET\training\gt\21_manual1.png"

image = cv2.imread(x_path)
plt.imshow(image)

xlx
image = cv2.resize(image, (128,128))[:,:,0]

#displacement_val = np.random.randn(2, 3, 3) * 5
#displacement = tf.Variable(displacement_val)
#image = etf.deform_grid(image, displacement, order=3)
plt.imshow(image)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-7cbaa03fd7b7> in <module>
#       7 displacement_val = np.random.randn(2, 3, 3) * 5
#       8 displacement = tf.Variable(displacement_val)
# ----> 9 image = etf.deform_grid(image, displacement, order=3)
#      10 plt.imshow(image)
#      11
#
# C:\ProgramData\Anaconda3\lib\site-packages\elasticdeform\tf.py in deform_grid(X, displacement, *args, **kwargs)
#      52         return f(displacement, *X)
#      53     else:
# ---> 54         return f(displacement, X)[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\ops\custom_gradient.py in __call__(self, *a, **k)
#     254
#     255   def __call__(self, *a, **k):
# --> 256     return self._d(self._f, a, k)
#     257
#     258
#
# ...
